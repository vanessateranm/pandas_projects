# %%
import pandas as pd

# %%
ls
# Out:
# BMO.csv         CVE.csv         IMO.csv         TRP.csv
# CNQ.csv         ENB.csv         IPL.csv         Untitled.ipynb

# %%
bmo.head()
# Out:
#       date    BMO
# 0  5/14/19  66.97
# 1  5/13/19  66.49
# 2  5/10/19  67.22
# 3   5/9/19  66.04
# 4   5/8/19  66.02

# %%
"

# %%
cnq = pd.read_csv("CNQ.csv", index_col="date") 
bmo = pd.read_csv("BMO.csv", index_col="date") 
cve = pd.read_csv("CVE.csv", index_col="date") 
enb = pd.read_csv("ENB.csv", index_col="date") 
imo = pd.read_csv("IMO.csv", index_col="date") 
ipl = pd.read_csv("IPL.csv", index_col="date") 
trp = pd.read_csv("TRP.csv", index_col="date")

# %%
pd.concat([bmo,cnq,cve,enb,imo,ipl,trp],axis="columns",join="inner")
# Out:
#              BMO     CNQ    CVE    ENB    IMO     IPL      TRP
# date
# 5/14/19  66.9700  191.62  45.17  27.32  38.51  162.04  41.9700
# 5/13/19  66.4900  190.34  44.76  26.24  37.38  158.45  40.9900
# 5/10/19  67.2200  194.58  46.20  27.96  38.94  168.82  42.8300
# 5/9/19   66.0400  194.58  46.62  27.21  39.27  170.19  43.2500
# 5/8/19   66.0200  195.17  49.24  27.09  39.75  173.92  43.7000
# ...          ...     ...    ...    ...    ...     ...      ...
# 5/20/09  12.3299   23.83  15.58   4.50   4.80    9.73  10.4677
# 5/19/09  12.3875   24.63  15.65   4.39   4.85    9.45  10.5871
# 5/18/09  12.1925   26.02  15.52   4.14   4.68    9.27  10.4975
# 5/15/09  11.7316   24.40  15.19   4.01   4.24    8.74   9.9701
# 5/14/09  11.9665   24.53  15.54   4.24   4.55    8.52  10.2488
#
# [2517 rows x 7 columns]

# %%
combined=pd.concat([bmo,cnq,cve,enb,imo,ipl,trp],axis="columns",join="inner")
combined.head()
# Out:
#            BMO     CNQ    CVE    ENB    IMO     IPL    TRP
# date
# 5/14/19  66.97  191.62  45.17  27.32  38.51  162.04  41.97
# 5/13/19  66.49  190.34  44.76  26.24  37.38  158.45  40.99
# 5/10/19  67.22  194.58  46.20  27.96  38.94  168.82  42.83
# 5/9/19   66.04  194.58  46.62  27.21  39.27  170.19  43.25
# 5/8/19   66.02  195.17  49.24  27.09  39.75  173.92  43.70

# %%
combined.pct_change().dropna()
# Out:
#               BMO       CNQ       CVE       ENB       IMO       IPL       TRP
# date
# 5/13/19 -0.007167 -0.006680 -0.009077 -0.039531 -0.029343 -0.022155 -0.023350
# 5/10/19  0.010979  0.022276  0.032172  0.065549  0.041734  0.065447  0.044889
# 5/9/19  -0.017554  0.000000  0.009091 -0.026824  0.008475  0.008115  0.009806
# 5/8/19  -0.000303  0.003032  0.056199 -0.004410  0.012223  0.021917  0.010405
# 5/7/19   0.004696 -0.002049  0.025183 -0.015873  0.012830 -0.004657  0.001373
# ...           ...       ...       ...       ...       ...       ...       ...
# 5/20/09  0.014214  0.041066  0.026350  0.036866  0.048035  0.006205  0.010571
# 5/19/09  0.004672  0.033571  0.004493 -0.024444  0.010417 -0.028777  0.011407
# 5/18/09 -0.015742  0.056435 -0.008307 -0.056948 -0.035052 -0.019048 -0.008463
# 5/15/09 -0.037802 -0.062260 -0.021263 -0.031401 -0.094017 -0.057174 -0.050241
# 5/14/09  0.020023  0.005328  0.023041  0.057357  0.073113 -0.025172  0.027954
#
# [2516 rows x 7 columns]

# %%
combined.corr()
# Out:
#           BMO       CNQ       CVE       ENB       IMO       IPL       TRP
# BMO  1.000000  0.746358  0.758800  0.457306  0.806984  0.626053  0.764274
# CNQ  0.746358  1.000000  0.933007  0.587748  0.840312  0.849410  0.974018
# CVE  0.758800  0.933007  1.000000  0.666676  0.893173  0.866886  0.935083
# ENB  0.457306  0.587748  0.666676  1.000000  0.588189  0.791445  0.652670
# IMO  0.806984  0.840312  0.893173  0.588189  1.000000  0.843455  0.868179
# IPL  0.626053  0.849410  0.866886  0.791445  0.843455  1.000000  0.904970
# TRP  0.764274  0.974018  0.935083  0.652670  0.868179  0.904970  1.000000

# %%
import seaborn as sns

# %%
correlation=combined.corr()

# %%
correlation
# Out:
#           BMO       CNQ       CVE       ENB       IMO       IPL       TRP
# BMO  1.000000  0.746358  0.758800  0.457306  0.806984  0.626053  0.764274
# CNQ  0.746358  1.000000  0.933007  0.587748  0.840312  0.849410  0.974018
# CVE  0.758800  0.933007  1.000000  0.666676  0.893173  0.866886  0.935083
# ENB  0.457306  0.587748  0.666676  1.000000  0.588189  0.791445  0.652670
# IMO  0.806984  0.840312  0.893173  0.588189  1.000000  0.843455  0.868179
# IPL  0.626053  0.849410  0.866886  0.791445  0.843455  1.000000  0.904970
# TRP  0.764274  0.974018  0.935083  0.652670  0.868179  0.904970  1.000000

# %%
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #From the correlation matrix, the stock from ENB has the least correlation to BMO and CNQ  and should be added to the portfolio
